# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv("KS_train_data.csv")

# %%
df.describe()
# Out:
#        backers_count  converted_pledged_amount    created_at      deadline  \
# count  100000.000000              1.000000e+05  1.000000e+05  1.000000e+05
# mean      151.089430              1.241108e+04  1.400524e+09  1.406896e+09
# std      1163.024964              1.005545e+05  6.334581e+07  6.340574e+07
# min         0.000000              0.000000e+00  1.240366e+09  1.243556e+09
# 25%         4.000000              1.250000e+02  1.349203e+09  1.357171e+09
# 50%        28.000000              1.650000e+03  1.408426e+09  1.415244e+09
# 75%        86.000000              6.271250e+03  1.447206e+09  1.454243e+09
# max    105857.000000              1.026684e+07  1.517539e+09  1.518702e+09
#
#              fx_rate          goal   launched_at       pledged   usd_pledged
# count  100000.000000  1.000000e+05  1.000000e+05  1.000000e+05  1.000000e+05
# mean        1.017654  4.447512e+04  1.403972e+09  1.312485e+04  1.241284e+04
# ...

# %%
df.head()
# Out:
#   project_id  backers_count  \
# 0  KS_000000             80
# 1  KS_000001             82
# 2  KS_000002             21
# 3  KS_000003             37
# 4  KS_000004            153
#
#                                                blurb category  \
# 0  I will be an artist-in-residence at Elsewhere ...      art
# 1  1000 Artists is a public art-making installati...      art
# 2  The Sequel to ‘My Favorite Machine”, "MyPhoneH...      art
# 3  A film exploring the role and value of art edu...      art
# 4  We need to build a kitchen for Habitable Space...      art
#
#    converted_pledged_amount country  created_at currency    deadline  fx_rate  \
# 0                      3596      US  1325980505      USD  1334866560      1.0
# 1                      4586      US  1330926084      USD  1336440145      1.0
# 2                      5217      US  1332382894      USD  1338175739      1.0
# 3                      7160      GB  1332342451      USD  1334806096      1.0
# ...

# %%
df.features()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13596/1683800403.py in <module>
# ----> 1 df.features()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'features'

# %%
corrmat = df.corr()
# sns.heatmap(corrmat,annot=True,figsize=(10,10))

fig, ax = plt.subplots(figsize=(25,16))         # Sample figsize in inches
sns.set(font_scale=0.8)
sns.heatmap(corrmat, annot=True, linewidths=.5, ax=ax, fmt = ".2f", annot_kws={"size":18})
# Out:
# <AxesSubplot:>

# %%
sns.prob(x=df.category, y=df.funded)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13596/3312636365.py in <module>
# ----> 1 sns.prob(x=df.category, y=df.funded)
#
# AttributeError: module 'seaborn' has no attribute 'prob'

# %%
stats.probplot(df.goal, plot=plt)
# Out:
# ((array([-4.34602155, -4.14724578, -4.03913009, ...,  4.03913009,
#           4.14724578,  4.34602155]),
#   array([1.e-02, 1.e+00, 1.e+00, ..., 1.e+08, 1.e+08, 1.e+08])),
#  (124550.48581435131, 44475.11549300006, 0.09915795250208663))
